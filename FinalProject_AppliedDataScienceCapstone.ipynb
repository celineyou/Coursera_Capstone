# %% [markdown]
# **APPLIED DATA SCIENCE CAPSTONE - FINAL PROJECT**
#
#
# ---

# %% [markdown]
# Import libraries

# %%
import requests
import pandas as pd

# %% [markdown]
# Get data from a wikipedia page and convert the data into a table

# %%
wiki = 'https://fr.wikipedia.org/wiki/Liste_des_quartiers_administratifs_de_Paris'
wikipedia_page = requests.get(wiki)

df_raw = pd.read_html(wikipedia_page.content, header=0)[0]
myColumns = ['Arrondissement[1],[n 1]','Quartiers.1']
df = df_raw[myColumns]
df
# Out:
#                           Arrondissement[1],[n 1]                Quartiers.1
# 0             1er arrondissementdit « du Louvre »  Saint-Germain-l'Auxerrois
# 1             1er arrondissementdit « du Louvre »                     Halles
# 2             1er arrondissementdit « du Louvre »               Palais-Royal
# 3             1er arrondissementdit « du Louvre »              Place-Vendôme
# 4           2e arrondissementdit « de la Bourse »                    Gaillon
# ..                                            ...                        ...
# 75  19e arrondissementdit « des Buttes-Chaumont »                     Combat
# 76      20e arrondissementdit « de Ménilmontant »                 Belleville
# 77      20e arrondissementdit « de Ménilmontant »              Saint-Fargeau
# 78      20e arrondissementdit « de Ménilmontant »              Père-Lachaise
# 79      20e arrondissementdit « de Ménilmontant »                   Charonne
#
# [80 rows x 2 columns]

# %% [markdown]
# Group neighbourhood belonging to the same borough

# %%
df_paris = df.groupby(['Arrondissement[1],[n 1]'])['Quartiers.1'].apply(lambda x: ', '.join(x))
df_paris = df_paris.reset_index()
df_paris.rename(columns = {'Arrondissement[1],[n 1]':'Borough'}, inplace = True)
df_paris.rename(columns = {'Quartiers.1':'Neighbourhood'}, inplace = True)
df_paris
# Out:
#                                               Borough                                      Neighbourhood
# 0             10e arrondissementdit « de l'Entrepôt »  Saint-Vincent-de-Paul, Porte-Saint-Denis, Port...
# 1             11e arrondissementdit « de Popincourt »  Folie-Méricourt, Saint-Ambroise, Roquette, Sai...
# 2                12e arrondissementdit « de Reuilly »              Bel-Air, Picpus, Bercy, Quinze-Vingts
# 3              13e arrondissementdit « des Gobelins »     Salpêtrière, Gare, Maison-Blanche, Croulebarbe
# 4         14e arrondissementdit « de l'Observatoire »  Montparnasse, Parc-de-Montsouris, Petit-Montro...
# 5              15e arrondissementdit « de Vaugirard »             Saint-Lambert, Necker, Grenelle, Javel
# 6                  16e arrondissementdit « de Passy »          Auteuil, Muette, Porte-Dauphine, Chaillot
# 7   17e arrondissementdit « des Batignolles-Moncea...  Ternes, Plaine-de-Monceaux, Batignolles, Épine...
# 8     18e arrondissementdit « des Buttes-Montmartre »  Grandes-Carrières, Clignancourt, Goutte-d'Or, ...
# 9       19e arrondissementdit « des Buttes-Chaumont »        Villette, Pont-de-Flandre, Amérique, Combat
# 10                1er arrondissementdit « du Louvre »  Saint-Germain-l'Auxerrois, Halles, Palais-Roya...
# 11          20e arrondissementdit « de Ménilmontant »  Belleville, Saint-Fargeau, Père-Lachaise, Char...
# 12              2e arrondissementdit « de la Bourse »            Gaillon, Vivienne, Mail, Bonne-Nouvelle
# 13                 3e arrondissementdit « du Temple »  Arts-et-Métiers, Enfants-Rouges, Archives, Sai...
# 14       4e arrondissementdit « de l'Hôtel-de-Ville »    Saint-Merri, Saint-Gervais, Arsenal, Notre-Dame
# 15               5e arrondissementdit « du Panthéon »  Saint-Victor, Jardin-des-Plantes, Val-de-Grâce...
# 16             6e arrondissementdit « du Luxembourg »  Monnaie, Odéon, Notre-Dame-des-Champs, Saint-G...
# 17         7e arrondissementdit « du Palais-Bourbon »  Saint-Thomas-d'Aquin, Invalides, École-Militai...
# 18               8e arrondissementdit « de l'Élysée »  Champs-Élysées, Faubourg-du-Roule, Madeleine, ...
# 19                9e arrondissementdit « de l'Opéra »  Saint-Georges, Chaussée-d'Antin, Faubourg-Mont...

# %% [markdown]
# Get the size of our dataframe

# %%
df_paris.shape
# Out:
# (20, 2)

# %% [markdown]
# Add 2 columns to the dataframe containing the coordinates (latitude and longitude) of each borough

# %%
df_paris['Latitude']=[48.8709,48.8574,48.8412,48.8322,48.8331,48.8412,48.8637,48.8835,48.8925,48.8817,48.8592,48.8646,48.8655,48.8637,48.8601,48.8448,48.8493,48.8565,48.8763,48.8718]
df_paris['Longitude']=[2.3561,2.3795,2.3876,2.3561,2.3264,2.3003,2.2769,2.3219,2.3444,2.3822,2.3417, 2.3984,2.3426, 2.3615,2.3507,2.3471, 2.330,2.321,2.3183,2.3399]
df_paris
# Out:
#                                               Borough  ... Longitude
# 0             10e arrondissementdit « de l'Entrepôt »  ...    2.3561
# 1             11e arrondissementdit « de Popincourt »  ...    2.3795
# 2                12e arrondissementdit « de Reuilly »  ...    2.3876
# 3              13e arrondissementdit « des Gobelins »  ...    2.3561
# 4         14e arrondissementdit « de l'Observatoire »  ...    2.3264
# 5              15e arrondissementdit « de Vaugirard »  ...    2.3003
# 6                  16e arrondissementdit « de Passy »  ...    2.2769
# 7   17e arrondissementdit « des Batignolles-Moncea...  ...    2.3219
# 8     18e arrondissementdit « des Buttes-Montmartre »  ...    2.3444
# 9       19e arrondissementdit « des Buttes-Chaumont »  ...    2.3822
# 10                1er arrondissementdit « du Louvre »  ...    2.3417
# 11          20e arrondissementdit « de Ménilmontant »  ...    2.3984
# 12              2e arrondissementdit « de la Bourse »  ...    2.3426
# 13                 3e arrondissementdit « du Temple »  ...    2.3615
# 14       4e arrondissementdit « de l'Hôtel-de-Ville »  ...    2.3507
# 15               5e arrondissementdit « du Panthéon »  ...    2.3471
# 16             6e arrondissementdit « du Luxembourg »  ...    2.3300
# 17         7e arrondissementdit « du Palais-Bourbon »  ...    2.3210
# 18               8e arrondissementdit « de l'Élysée »  ...    2.3183
# 19                9e arrondissementdit « de l'Opéra »  ...    2.3399
#
# [20 rows x 4 columns]

# %% [markdown]
# Use Geopy to find geographical coordinates

# %%
from geopy.geocoders import Nominatim 

address = 'Paris, France'

geolocator = Nominatim(user_agent="paris_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates of Paris are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Paris are 48.8566969, 2.3514616.

# %% [markdown]
# Let's display a map of Paris with its 20 boroughs

# %%
import folium

# create map of Paris using latitude and longitude values
map_Paris = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighbourhood in zip(df_paris['Latitude'], df_paris['Longitude'], df_paris['Borough'], df_paris['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        ).add_to(map_Paris)  

map_Paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Use Foursquare API

# %%
CLIENT_ID = 'MZD2YKAEVGPL0SOZW0T4TFR0UQM2FEC24WZJRS2IJZS0ZTFP' # your Foursquare ID
CLIENT_SECRET = 'BM325RX2K13OLADN3XPVSPLRL05LMKSYAJOEXLPW0IYJEX0L' # your Foursquare Secret
VERSION = '20180604' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: MZD2YKAEVGPL0SOZW0T4TFR0UQM2FEC24WZJRS2IJZS0ZTFP
# CLIENT_SECRET:BM325RX2K13OLADN3XPVSPLRL05LMKSYAJOEXLPW0IYJEX0L

# %% [markdown]
# Explore and get venues in Paris

# %%
radius = 5000
LIMIT = 200
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=MZD2YKAEVGPL0SOZW0T4TFR0UQM2FEC24WZJRS2IJZS0ZTFP&client_secret=BM325RX2K13OLADN3XPVSPLRL05LMKSYAJOEXLPW0IYJEX0L&ll=48.8566969,2.3514616&v=20180604&radius=5000&limit=200'

# %%
import requests
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Create a dataframe with the venues found

# %%
import json
from pandas.io.json import json_normalize

venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

dataframe = pd.json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(20)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  name  ...                        id
# 0   Place de l'Hôtel de Ville – Esplanade de la Li...  ...  4bf41231e5eba59334341f90
# 1                      Cathédrale Notre-Dame de Paris  ...  4adcda09f964a520e83321e3
# 2                         Boutique du Centre Pompidou  ...  5113ebbce4b0d3c1022aef14
# 3                                    Comme à Lisbonne  ...  4e0757e96284d9ee92d4b1ca
# 4                                    Comptoir Gourmet  ...  512534ece4b03a94f9a50313
# 5      Centre Pompidou – Musée National d'Art Moderne  ...  4adcda0af964a520623421e3
# 6                               Shakespeare & Company  ...  4adcda21f964a520f23921e3
# 7                                              Miznon  ...  526d201d11d2d42b81af4ee6
# 8                                           59 Rivoli  ...  4e0766702271dfa46baee474
# 9                                        Glace Bachir  ...  58728968d4ab735c99ae0c5e
# 10                                     Place Dauphine  ...  4adcda09f964a520eb3321e3
# 11                               La Maison d'Isabelle  ...  5b394cae92e7a9002c724cf9
# 12                                        LEGO® Store  ...  57035c8b498ebcbc85d70c40
# 13                                 Ze Kitchen Galerie  ...  4b4b6fe4f964a520a19b26e3
# 14                                          Chez Nous  ...  53568d3e498e92e5a3a56f36
# 15                                 Bistro du Périgord  ...  50d5be47e4b0fb6ff8363c5f
# 16                                    Place du Louvre  ...  4f979c8ae4b05465dae0714f
# 17                                       Album Comics  ...  4b588679f964a5201c5c28e3
# 18                          Fromagerie Laurent Dubois  ...  4b23ab0cf964a520ce5724e3
# 19                                   Chez Le Libanais  ...  4adcda08f964a520963321e3
#
# [20 rows x 16 columns]

# %% [markdown]
# Display a map of Paris with the venues

# %%
import folium

# create map of Paris using latitude and longitude values
mapParis = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, borough, neighbourhood in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['name'], dataframe_filtered['address']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        ).add_to(mapParis)  

mapParis
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Get venues around the different boroughs

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Borough', 
                  'Borough Latitude', 
                  'Borough Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
paris_venues = getNearbyVenues(names=df_paris['Borough'],
                                   latitudes=df_paris['Latitude'],
                                   longitudes=df_paris['Longitude']
                                  )
# Out:
# 10e arrondissementdit « de l'Entrepôt »
# 11e arrondissementdit « de Popincourt »
# 12e arrondissementdit « de Reuilly »
# 13e arrondissementdit « des Gobelins »
# 14e arrondissementdit « de l'Observatoire »
# 15e arrondissementdit « de Vaugirard »
# 16e arrondissementdit « de Passy »
# 17e arrondissementdit « des Batignolles-Monceaux »
# 18e arrondissementdit « des Buttes-Montmartre »
# 19e arrondissementdit « des Buttes-Chaumont »
# 1er arrondissementdit « du Louvre »
# 20e arrondissementdit « de Ménilmontant »
# 2e arrondissementdit « de la Bourse »
# 3e arrondissementdit « du Temple »
# 4e arrondissementdit « de l'Hôtel-de-Ville »
# 5e arrondissementdit « du Panthéon »
# 6e arrondissementdit « du Luxembourg »
# 7e arrondissementdit « du Palais-Bourbon »
# 8e arrondissementdit « de l'Élysée »
# 9e arrondissementdit « de l'Opéra »

# %%
print(paris_venues.shape)
paris_venues.head()
# Out:
# (1343, 7)
#                                    Borough  ...  Venue Category
# 0  10e arrondissementdit « de l'Entrepôt »  ...    Cocktail Bar
# 1  10e arrondissementdit « de l'Entrepôt »  ...           Hotel
# 2  10e arrondissementdit « de l'Entrepôt »  ...          Bistro
# 3  10e arrondissementdit « de l'Entrepôt »  ...     Pizza Place
# 4  10e arrondissementdit « de l'Entrepôt »  ...  Sandwich Place
#
# [5 rows x 7 columns]

# %%
paris_venues.groupby('Borough').count()
# Out:
#                                                     Borough Latitude  ...  Venue Category
# Borough                                                               ...
# 10e arrondissementdit « de l'Entrepôt »                           62  ...              62
# 11e arrondissementdit « de Popincourt »                           98  ...              98
# 12e arrondissementdit « de Reuilly »                              42  ...              42
# 13e arrondissementdit « des Gobelins »                            52  ...              52
# 14e arrondissementdit « de l'Observatoire »                       47  ...              47
# 15e arrondissementdit « de Vaugirard »                            52  ...              52
# 16e arrondissementdit « de Passy »                                23  ...              23
# 17e arrondissementdit « des Batignolles-Monceaux »                92  ...              92
# 18e arrondissementdit « des Buttes-Montmartre »                   53  ...              53
# 19e arrondissementdit « des Buttes-Chaumont »                     32  ...              32
# 1er arrondissementdit « du Louvre »                               70  ...              70
# 20e arrondissementdit « de Ménilmontant »                         53  ...              53
# 2e arrondissementdit « de la Bourse »                            100  ...             100
# 3e arrondissementdit « du Temple »                                99  ...              99
# 4e arrondissementdit « de l'Hôtel-de-Ville »                      88  ...              88
# 5e arrondissementdit « du Panthéon »                             100  ...             100
# 6e arrondissementdit « du Luxembourg »                            68  ...              68
# 7e arrondissementdit « du Palais-Bourbon »                        87  ...              87
# 8e arrondissementdit « de l'Élysée »                              46  ...              46
# 9e arrondissementdit « de l'Opéra »                               79  ...              79
#
# [20 rows x 6 columns]

# %% [markdown]
# Indicate the categories of the venues

# %%
# one hot encoding
paris_onehot = pd.get_dummies(paris_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
paris_onehot['Borough'] = paris_venues['Borough'] 

# move neighborhood column to the first column
fixed_columns = [paris_onehot.columns[-1]] + list(paris_onehot.columns[:-1])
paris_onehot = paris_onehot[fixed_columns]

paris_onehot.head()
# Out:
#                                    Borough  ...  Women's Store
# 0  10e arrondissementdit « de l'Entrepôt »  ...              0
# 1  10e arrondissementdit « de l'Entrepôt »  ...              0
# 2  10e arrondissementdit « de l'Entrepôt »  ...              0
# 3  10e arrondissementdit « de l'Entrepôt »  ...              0
# 4  10e arrondissementdit « de l'Entrepôt »  ...              0
#
# [5 rows x 197 columns]

# %%
paris_onehot.shape
# Out:
# (1343, 197)

# %%
paris_grouped = paris_onehot.groupby('Borough').mean().reset_index()
paris_grouped.head()
# Out:
#                                        Borough  ...  Women's Store
# 0      10e arrondissementdit « de l'Entrepôt »  ...       0.000000
# 1      11e arrondissementdit « de Popincourt »  ...       0.010204
# 2         12e arrondissementdit « de Reuilly »  ...       0.000000
# 3       13e arrondissementdit « des Gobelins »  ...       0.000000
# 4  14e arrondissementdit « de l'Observatoire »  ...       0.000000
#
# [5 rows x 197 columns]

# %%
paris_grouped.shape
# Out:
# (20, 197)

# %% [markdown]
# Let's find the most common venues in each borough of Paris

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
import numpy as np
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Borough']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Borough'] = paris_grouped['Borough']

for ind in np.arange(paris_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(paris_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(20)
# Out:
#                                               Borough  ... 10th Most Common Venue
# 0             10e arrondissementdit « de l'Entrepôt »  ...                   Café
# 1             11e arrondissementdit « de Popincourt »  ...                 Bakery
# 2                12e arrondissementdit « de Reuilly »  ...         Sandwich Place
# 3              13e arrondissementdit « des Gobelins »  ...                    Gym
# 4         14e arrondissementdit « de l'Observatoire »  ...                  Plaza
# 5              15e arrondissementdit « de Vaugirard »  ...                    Bar
# 6                  16e arrondissementdit « de Passy »  ...                 Garden
# 7   17e arrondissementdit « des Batignolles-Moncea...  ...            Pizza Place
# 8     18e arrondissementdit « des Buttes-Montmartre »  ...  Vietnamese Restaurant
# 9       19e arrondissementdit « des Buttes-Chaumont »  ...            Beer Garden
# 10                1er arrondissementdit « du Louvre »  ...                Exhibit
# 11          20e arrondissementdit « de Ménilmontant »  ...       Sushi Restaurant
# 12              2e arrondissementdit « de la Bourse »  ...             Restaurant
# 13                 3e arrondissementdit « du Temple »  ...           Cocktail Bar
# 14       4e arrondissementdit « de l'Hôtel-de-Ville »  ...           Cocktail Bar
# 15               5e arrondissementdit « du Panthéon »  ...                  Plaza
# 16             6e arrondissementdit « du Luxembourg »  ...             Restaurant
# 17         7e arrondissementdit « du Palais-Bourbon »  ...                 Garden
# 18               8e arrondissementdit « de l'Élysée »  ...                    Bar
# 19                9e arrondissementdit « de l'Opéra »  ...           Cocktail Bar
#
# [20 rows x 11 columns]
